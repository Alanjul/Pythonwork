# %%
import pandas as pd
import matplotlib.pyplot as plt
#converting the temperature to celcius
c = lambda f: 5/9*(f-32)

#tuple to display Fahrenheit temperature to their corresponding celsius temp
temp = [(f, c(f)) for f in range(0,101, 10)]
print(temp, ' ')
Fa = lambda ca: (9/5 *ca)+32
temp1 = [(ca, Fa(ca)) for ca in range(0,40, 5) ]
print(temp1, ' ')

temps_df = pd.DataFrame(temp1, columns=['Celsius', 'Fahrenheit'])
print("Tables showing degrees in Celsius converted to Fahrenheit")
print(temps_df)
axes = temps_df.plot(x='Celsius', y='Fahrenheit', style='.-')
print("The graphs showing Fahrenheit converted Celsius")
temp_df = pd.DataFrame(temp, columns=['Fahrenheit', 'Celsius'])
print("Tables showing degrees in Fahrenheit converted to Celsius and the graph")
print(temp_df)
axes1 = temp_df.plot(x='Fahrenheit', y='Celsius', style='.-')
# Out:
# [(0, -17.77777777777778), (10, -12.222222222222223), (20, -6.666666666666667), (30, -1.1111111111111112), (40, 4.444444444444445), (50, 10.0), (60, 15.555555555555557), (70, 21.11111111111111), (80, 26.666666666666668), (90, 32.22222222222222), (100, 37.77777777777778)]
# [(0, 32.0), (5, 41.0), (10, 50.0), (15, 59.0), (20, 68.0), (25, 77.0), (30, 86.0), (35, 95.0)]
# Tables showing degrees in Celsius converted to Fahrenheit
#    Celsius  Fahrenheit
# 0        0        32.0
# 1        5        41.0
# 2       10        50.0
# 3       15        59.0
# 4       20        68.0
# 5       25        77.0
# 6       30        86.0
# 7       35        95.0
# The graphs showing Fahrenheit converted Celsius
# Tables showing degrees in Fahrenheit converted to Celsius
#     Fahrenheit    Celsius
# 0            0 -17.777778
# 1           10 -12.222222
# 2           20  -6.666667
# 3           30  -1.111111
# 4           40   4.444444
# 5           50  10.000000
# 6           60  15.555556
# 7           70  21.111111
# 8           80  26.666667
# 9           90  32.222222
# 10         100  37.777778
